# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import csv
import time
import datetime
import smtplib

# %%
URL = 'https://www.tokopedia.com/gmg-hobbies/pr64004-pop-race-gr-yaris-pandem-metallic-red-toyota-poprace-diecast?source=homepage.top_carousel.0.38456'
headers = {"Accept": "application/json",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.5",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20100101 Firefox/123.0",
    "X-Amzn-Trace-Id": "Root=1-65e026f0-0e7e2f7a6ab17a0a4a54d462"}
page = requests.get(URL, headers=headers)

# %%
raw_soup = BeautifulSoup(page.content, 'html.parser')
soup = BeautifulSoup(raw_soup.prettify(), 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="id" translate="no">
# <head>
# <title data-rh="true">
#    Jual PR64004 Pop Race GR Yaris Pandem Metallic Red Toyota PopRace Diecast -  - GMG-Hobbies | Tokopedia
#   </title>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=yes, width=device-width" name="viewport"/>
# <link crossorigin="" href="https://assets.tokopedia.net" rel="preconnect"/>
# <link href="https://assets.tokopedia.net" nonce="BsA6vgFKC66h+Mkp/2mQZw==" rel="dns-prefetch"/>
# <link crossorigin="" href="https://gql.tokopedia.com" rel="preconnect"/>
# <link href="https://gql.tokopedia.com" nonce="BsA6vgFKC66h+Mkp/2mQZw==" rel="dns-prefetch"/>
# <link crossorigin="" href="https://googleads.g.doubleclick.net" rel="preconnect"/>
# <link href="https://googleads.g.doubleclick.net" nonce="BsA6vgFKC66h+Mkp/2mQZw==" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/>
# ...

# %%
title = soup.find('h1', class_="css-1os9jjn",  attrs={"data-testid": "lblPDPDetailProductName"}).get_text().strip()
price = soup.find('div', class_="price", attrs={'data-testid':"lblPDPDetailProductPrice"}).get_text().strip()

# %%
print(title)
print(price)
# Out:
# PR64004 Pop Race GR Yaris Pandem Metallic Red Toyota PopRace Diecast
# Rp599.900

# %%
today = datetime.date.today()
print(today)
# Out:
# 2024-03-03

# %%
header=['Item Name','Price','Date']
data=[title,price,today]

# %%
#with open('TokopediaWebScrapingDataset.csv', 'w', newline='', encoding='UTF8') as f:
    #writer = csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Python\Python Data Analysis Project\TokopediaWebScrapingDataset.csv")
df

# %%
with open('TokopediaWebScrapingDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    import pandas as pd
    from bs4 import BeautifulSoup
    import requests
    import csv
    import time
    import datetime
    import smtplib

    URL = 'https://www.tokopedia.com/gmg-hobbies/pr64004-pop-race-gr-yaris-pandem-metallic-red-toyota-poprace-diecast?source=homepage.top_carousel.0.38456'
    headers = {"Accept": "application/json",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en-US,en;q=0.5",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20100101 Firefox/123.0",
        "X-Amzn-Trace-Id": "Root=1-65e026f0-0e7e2f7a6ab17a0a4a54d462"}
    page = requests.get(URL, headers=headers)

    raw_soup = BeautifulSoup(page.content, 'html.parser')
    soup = BeautifulSoup(raw_soup.prettify(), 'html.parser')
    title = soup.find('h1', class_="css-1os9jjn",  attrs={"data-testid": "lblPDPDetailProductName"}).get_text().strip()
    price = soup.find('div', class_="price", attrs={'data-testid':"lblPDPDetailProductPrice"}).get_text().strip()
    today = datetime.date.today()

    header=['Item Name','Price','Date']
    data=[title,price,today]

    with open('TokopediaWebScrapingDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    import time
    check_price()
    time.sleep(30)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[31], line 3
#       1 while(True):
#       2     import time
# ----> 3     check_price()
#       4     time.sleep(30)
#
# Cell In[29], line 27, in check_price()
#      24 header=['Item Name','Price','Date']
#      25 data=[title,price,today]
# ---> 27 with open('TokopediaWebScrapingDataset.csv', 'a+', newline='', encoding='UTF8') as f:
#      28     writer = csv.writer(f)
#      29     writer.writerow(data)
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# ...
